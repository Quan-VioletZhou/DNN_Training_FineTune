# %%
# Training data stimuli generation script
# Mixed speec and randomized noise background

import os
import random
import numpy as np
import librosa
import soundfile as sf
import csv

def adjust_snr(speech, noise, target_snr_db):
    """Adjust the noise to match the target SNR."""
    speech_power = np.mean(speech**2)
    noise_power = np.mean(noise**2)
    desired_noise_power = speech_power / (10**(target_snr_db / 10))
    scaling_factor = np.sqrt(desired_noise_power / (noise_power + 1e-8))
    return noise * scaling_factor

def mix_speech_with_noise(speech_dir, noise_dirs, output_dir, csv_log, num_samples=None):
    """Mix each speech clip with a randomly chosen noise clip at a random SNR and log details."""
    os.makedirs(output_dir, exist_ok=True)
    speech_files = [f for f in os.listdir(speech_dir) if f.lower().endswith('.wav')]
    
    if num_samples:
        speech_files = random.sample(speech_files, num_samples)
    
    log_data = []
    
    for speech_file in speech_files:
        speech_path = os.path.join(speech_dir, speech_file)
        speech, sr = librosa.load(speech_path, sr=None)
        speech_length = len(speech)
        
        # Select a random noise category
        noise_type = random.choice(list(noise_dirs.keys()))
        noise_dir = noise_dirs[noise_type]
        noise_file = random.choice([f for f in os.listdir(noise_dir) if f.lower().endswith('.wav')])
        noise_path = os.path.join(noise_dir, noise_file)
        noise, _ = librosa.load(noise_path, sr=sr)
        
        # Ensure noise is exactly 2 seconds
        noise_length = sr * 2  # 2 seconds in samples
        if len(noise) > noise_length:
            noise = noise[:noise_length]
        elif len(noise) < noise_length:
            noise = np.pad(noise, (0, noise_length - len(noise)), mode='constant')
        
        # Center the speech within the 2-second noise
        start_idx = (len(noise) - speech_length) // 2
        mixed_noise = noise.copy()
        mixed_noise[start_idx:start_idx + speech_length] += speech
        
        # Determine SNR based on noise type
        if noise_type in ["babble", "scenes"]:
            snr = np.random.normal(-3, 2)
        else:
            snr = np.random.normal(-6, 2)
        
        mixed_noise = adjust_snr(speech, mixed_noise, snr)
        
        # Save mixed output
        output_path = os.path.join(output_dir, speech_file)
        sf.write(output_path, mixed_noise, sr)
        
        # Log details
        log_data.append([speech_file, noise_file, noise_type, snr])
        print(f"Processed: {speech_file} with {noise_type} at {snr:.2f} dB SNR")
    
    # Write CSV log
    with open(csv_log, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Speech File", "Noise File", "Noise Type", "SNR (dB)"])
        writer.writerows(log_data)

# Define directories
speech_dir = "D:/DNN/Training_data/TIMIT/Extracted_Clips_training"
noise_dirs = {
    "babble": "D:/DNN/Training_data/Noise/speaker_babble/Extracted_speaker_noise_new",
    "scenes": "D:/DNN/Training_data/Noise/scenes_stereo/Extracted_scenes_noise",
    "music": "D:/DNN/Training_data/Noise/Extracted_FMA_Instrumental"
}
output_dir = "D:/DNN/Training_data/Mixed_Training"
csv_log = "D:/DNN/Training_data/mixing_log.csv"

# Run processing
mix_speech_with_noise(speech_dir, noise_dirs, output_dir, csv_log)
# Out:
# Processed: greasy_FAKS0_SA1.WAV with music at -6.97 dB SNR
# Processed: greasy_FDAC1_SA1.WAV with babble at -4.15 dB SNR
# Processed: greasy_FELC0_SA1.WAV with scenes at -3.40 dB SNR
# Processed: greasy_FJEM0_SA1.WAV with music at -6.84 dB SNR
# Processed: greasy_MDAB0_SA1.WAV with scenes at -3.09 dB SNR
# Processed: greasy_MJSW0_SA1.WAV with babble at -5.15 dB SNR
# Processed: greasy_MREB0_SA1.WAV with babble at -7.65 dB SNR
# Processed: greasy_MRJO0_SA1.WAV with scenes at -2.01 dB SNR
# Processed: greasy_MSJS1_SA1.WAV with music at -6.65 dB SNR
# Processed: greasy_MSTK0_SA1.WAV with scenes at -0.59 dB SNR
# Processed: greasy_MWBT0_SA1.WAV with music at -6.47 dB SNR
# Processed: greasy_FCMR0_SA1.WAV with music at -6.74 dB SNR
# Processed: greasy_FDRD1_SA1.WAV with music at -3.79 dB SNR
# Processed: greasy_FJAS0_SA1.WAV with scenes at -3.22 dB SNR
# Processed: greasy_FJRE0_SA1.WAV with babble at -3.55 dB SNR
# Processed: greasy_FJWB0_SA1.WAV with music at -6.67 dB SNR
# Processed: greasy_FPAS0_SA1.WAV with scenes at -5.07 dB SNR
# Processed: greasy_FRAM1_SA1.WAV with scenes at -2.60 dB SNR
# Processed: greasy_FSLB1_SA1.WAV with music at -4.88 dB SNR
# Processed: greasy_MABW0_SA1.WAV with babble at 0.01 dB SNR
# Processed: greasy_MBJK0_SA1.WAV with scenes at 0.76 dB SNR
# Processed: greasy_MCCS0_SA1.WAV with scenes at -4.67 dB SNR
# Processed: greasy_MCEM0_SA1.WAV with music at -5.76 dB SNR
# Processed: greasy_MDBB0_SA1.WAV with music at -4.08 dB SNR
# Processed: greasy_MDLD0_SA1.WAV with music at -4.89 dB SNR
# Processed: greasy_MGWT0_SA1.WAV with scenes at -4.41 dB SNR
# Processed: greasy_MJAR0_SA1.WAV with music at -6.63 dB SNR
# Processed: greasy_MMDB1_SA1.WAV with music at -2.58 dB SNR
# Processed: greasy_MMDM2_SA1.WAV with music at -10.63 dB SNR
# Processed: greasy_MPDF0_SA1.WAV with scenes at -3.07 dB SNR
# Processed: greasy_MPGL0_SA1.WAV with babble at -2.92 dB SNR
# Processed: greasy_MRCZ0_SA1.WAV with music at -7.28 dB SNR
# Processed: greasy_MRGG0_SA1.WAV with music at -4.57 dB SNR
# Processed: greasy_MTAS1_SA1.WAV with scenes at 0.39 dB SNR
# Processed: greasy_MTMR0_SA1.WAV with babble at -2.37 dB SNR
# Processed: greasy_MWEW0_SA1.WAV with scenes at 0.35 dB SNR
# Processed: greasy_MWVW0_SA1.WAV with scenes at -3.91 dB SNR
# Processed: greasy_FCMH0_SA1.WAV with music at -7.87 dB SNR
# Processed: greasy_FKMS0_SA1.WAV with scenes at 0.54 dB SNR
# Processed: greasy_FPKT0_SA1.WAV with babble at -2.58 dB SNR
# Processed: greasy_MBDG0_SA1.WAV with babble at -1.24 dB SNR
# Processed: greasy_MBWM0_SA1.WAV with music at -9.38 dB SNR
# Processed: greasy_MCSH0_SA1.WAV with music at -3.52 dB SNR
# Processed: greasy_MCTW0_SA1.WAV with babble at -2.88 dB SNR
# Processed: greasy_MGJF0_SA1.WAV with babble at -2.63 dB SNR
# Processed: greasy_MGLB0_SA1.WAV with babble at -4.39 dB SNR
# Processed: greasy_MHPG0_SA1.WAV with scenes at -1.55 dB SNR
# Processed: greasy_MJBR0_SA1.WAV with scenes at -2.17 dB SNR
# Processed: greasy_MJES0_SA1.WAV with scenes at -2.11 dB SNR
# Processed: greasy_MJJG0_SA1.WAV with music at -9.71 dB SNR
# Processed: greasy_MJMP0_SA1.WAV with scenes at -6.55 dB SNR
# Processed: greasy_MJVW0_SA1.WAV with music at -4.05 dB SNR
# Processed: greasy_MKCH0_SA1.WAV with music at -4.45 dB SNR
# Processed: greasy_MLNT0_SA1.WAV with music at -5.88 dB SNR
# Processed: greasy_MMAB0_SA1.WAV with music at -9.87 dB SNR
# Processed: greasy_MMDH0_SA1.WAV with scenes at -1.10 dB SNR
# Processed: greasy_MMJR0_SA1.WAV with scenes at -3.92 dB SNR
# Processed: greasy_MMWH0_SA1.WAV with music at -4.15 dB SNR
# Processed: greasy_MRTK0_SA1.WAV with babble at -1.01 dB SNR
# Processed: greasy_MTAA0_SA1.WAV with scenes at -5.17 dB SNR
# Processed: greasy_MTDT0_SA1.WAV with scenes at -0.94 dB SNR
# Processed: greasy_MTHC0_SA1.WAV with scenes at -1.25 dB SNR
# Processed: greasy_MWJG0_SA1.WAV with music at -2.73 dB SNR
# Processed: greasy_FADG0_SA1.WAV with babble at -0.60 dB SNR
# Processed: greasy_FCFT0_SA1.WAV with music at -8.23 dB SNR
# Processed: greasy_FCRH0_SA1.WAV with scenes at -6.26 dB SNR
# Processed: greasy_FDMS0_SA1.WAV with scenes at -3.44 dB SNR
# Processed: greasy_FEDW0_SA1.WAV with babble at -3.05 dB SNR
# Processed: greasy_FGJD0_SA1.WAV with babble at 0.50 dB SNR
# Processed: greasy_FJLM0_SA1.WAV with babble at -2.12 dB SNR
# Processed: greasy_FJMG0_SA1.WAV with music at -6.58 dB SNR
# Processed: greasy_FLBW0_SA1.WAV with babble at -2.11 dB SNR
# Processed: greasy_FLKD0_SA1.WAV with scenes at -3.67 dB SNR
# Processed: greasy_FMAF0_SA1.WAV with scenes at -2.93 dB SNR
# Processed: greasy_FMCM0_SA1.WAV with babble at 0.86 dB SNR
# Processed: greasy_FNMR0_SA1.WAV with babble at -3.60 dB SNR
# Processed: greasy_FREW0_SA1.WAV with music at -3.46 dB SNR
# Processed: greasy_FRNG0_SA1.WAV with music at -4.49 dB SNR
# Processed: greasy_FSEM0_SA1.WAV with music at -3.24 dB SNR
# Processed: greasy_MBNS0_SA1.WAV with music at -8.78 dB SNR
# Processed: greasy_MDLS0_SA1.WAV with scenes at 0.04 dB SNR
# Processed: greasy_MDRM0_SA1.WAV with scenes at -2.62 dB SNR
# Processed: greasy_MGMM0_SA1.WAV with music at -4.72 dB SNR
# Processed: greasy_MJDM1_SA1.WAV with babble at -2.47 dB SNR
# Processed: greasy_MJRF0_SA1.WAV with babble at -5.67 dB SNR
# Processed: greasy_MKCL0_SA1.WAV with scenes at -4.06 dB SNR
# Processed: greasy_MLJB0_SA1.WAV with music at -6.21 dB SNR
# Processed: greasy_MLLL0_SA1.WAV with babble at -2.12 dB SNR
# Processed: greasy_MPCS0_SA1.WAV with babble at -3.70 dB SNR
# Processed: greasy_MPLB0_SA1.WAV with babble at -0.91 dB SNR
# Processed: greasy_MPWM0_SA1.WAV with music at -6.79 dB SNR
# Processed: greasy_MRKO0_SA1.WAV with music at -7.87 dB SNR
# Processed: greasy_MROA0_SA1.WAV with babble at -1.30 dB SNR
# Processed: greasy_MTEB0_SA1.WAV with babble at -2.29 dB SNR
# Processed: greasy_MTLS0_SA1.WAV with scenes at -3.01 dB SNR
# Processed: greasy_FASW0_SA1.WAV with scenes at -5.96 dB SNR
# Processed: greasy_FAWF0_SA1.WAV with babble at -2.93 dB SNR
# Processed: greasy_FCAL1_SA1.WAV with babble at 0.80 dB SNR
# Processed: greasy_FGMD0_SA1.WAV with babble at -3.35 dB SNR
# Processed: greasy_FHES0_SA1.WAV with babble at -3.70 dB SNR
# Processed: greasy_FHEW0_SA1.WAV with music at -9.23 dB SNR
# Processed: greasy_FJCS0_SA1.WAV with music at -2.60 dB SNR
# Processed: greasy_FJSA0_SA1.WAV with scenes at -2.51 dB SNR
# Processed: greasy_FMAH0_SA1.WAV with scenes at -7.06 dB SNR
# Processed: greasy_FNLP0_SA1.WAV with music at -3.11 dB SNR
# Processed: greasy_FUTB0_SA1.WAV with music at -9.60 dB SNR
# Processed: greasy_MAHH0_SA1.WAV with babble at -0.52 dB SNR
# Processed: greasy_MBPM0_SA1.WAV with music at -4.05 dB SNR
# Processed: greasy_MCMB0_SA1.WAV with scenes at -6.79 dB SNR
# Processed: greasy_MCRC0_SA1.WAV with scenes at -4.33 dB SNR
# Processed: greasy_MCTT0_SA1.WAV with babble at -2.75 dB SNR
# Processed: greasy_MDAC2_SA1.WAV with music at -5.35 dB SNR
# Processed: greasy_MDRB0_SA1.WAV with music at -6.07 dB SNR
# Processed: greasy_MDWA0_SA1.WAV with music at -6.87 dB SNR
# Processed: greasy_MDWK0_SA1.WAV with scenes at -0.39 dB SNR
# Processed: greasy_MFGK0_SA1.WAV with scenes at -5.47 dB SNR
# Processed: greasy_MKLT0_SA1.WAV with babble at -3.09 dB SNR
# Processed: greasy_MLIH0_SA1.WAV with scenes at 2.24 dB SNR
# Processed: greasy_MRJM3_SA1.WAV with music at -7.62 dB SNR
# Processed: greasy_MRPP0_SA1.WAV with babble at -3.51 dB SNR
# Processed: greasy_MRRK0_SA1.WAV with scenes at -4.04 dB SNR
# Processed: greasy_MRWS1_SA1.WAV with scenes at 1.08 dB SNR
# Processed: greasy_MSFH1_SA1.WAV with babble at -4.62 dB SNR
# Processed: greasy_FDRW0_SA1.WAV with music at -8.17 dB SNR
# Processed: greasy_FLNH0_SA1.WAV with scenes at -2.97 dB SNR
# Processed: greasy_FMGD0_SA1.WAV with scenes at -0.52 dB SNR
# Processed: greasy_MCMJ0_SA1.WAV with music at -5.58 dB SNR
# Processed: greasy_MDSC0_SA1.WAV with scenes at 0.12 dB SNR
# Processed: greasy_MESD0_SA1.WAV with scenes at 0.98 dB SNR
# Processed: greasy_MJDH0_SA1.WAV with babble at -4.68 dB SNR
# Processed: greasy_MJFC0_SA1.WAV with babble at -1.33 dB SNR
# Processed: greasy_MPAM1_SA1.WAV with scenes at -6.13 dB SNR
# Processed: greasy_MRJR0_SA1.WAV with music at -6.31 dB SNR
# Processed: greasy_MRJS0_SA1.WAV with babble at -4.64 dB SNR
# Processed: greasy_FCAU0_SA1.WAV with music at -8.33 dB SNR
# Processed: greasy_FDHC0_SA1.WAV with babble at -5.33 dB SNR
# Processed: greasy_FGWR0_SA1.WAV with scenes at -2.22 dB SNR
# Processed: greasy_FISB0_SA1.WAV with babble at -5.82 dB SNR
# Processed: greasy_FLAS0_SA1.WAV with music at -8.62 dB SNR
# Processed: greasy_FMML0_SA1.WAV with scenes at -0.90 dB SNR
# Processed: greasy_FSXA0_SA1.WAV with music at -4.22 dB SNR
# Processed: greasy_FTLH0_SA1.WAV with babble at -1.29 dB SNR
# Processed: greasy_MCHH0_SA1.WAV with scenes at 1.84 dB SNR
# Processed: greasy_MDLF0_SA1.WAV with babble at -1.51 dB SNR
# Processed: greasy_MDVC0_SA1.WAV with music at -9.94 dB SNR
# Processed: greasy_MERS0_SA1.WAV with babble at -0.95 dB SNR
# Processed: greasy_MGRT0_SA1.WAV with scenes at -3.91 dB SNR
# Processed: greasy_MKDR0_SA1.WAV with music at -4.20 dB SNR
# Processed: greasy_MKJL0_SA1.WAV with babble at -2.11 dB SNR
# Processed: greasy_MNJM0_SA1.WAV with babble at -2.42 dB SNR
# Processed: greasy_MNLS0_SA1.WAV with scenes at -3.62 dB SNR
# Processed: greasy_MPAB0_SA1.WAV with music at -5.25 dB SNR
# Processed: greasy_MRCS0_SA1.WAV with music at -6.54 dB SNR
# Processed: greasy_MRJM4_SA1.WAV with babble at -8.39 dB SNR
# Processed: greasy_MRMS1_SA1.WAV with babble at -4.67 dB SNR
# Processed: greasy_MRPC0_SA1.WAV with scenes at -8.05 dB SNR
# Processed: greasy_MTWH0_SA1.WAV with babble at -2.44 dB SNR
# Processed: greasy_FCMH1_SA1.WAV with music at -6.69 dB SNR
# Processed: greasy_FJSJ0_SA1.WAV with babble at -5.11 dB SNR
# Processed: greasy_FMLD0_SA1.WAV with scenes at -1.93 dB SNR
# Processed: greasy_MAJC0_SA1.WAV with babble at -3.91 dB SNR
# Processed: greasy_MDAW1_SA1.WAV with music at -5.13 dB SNR
# Processed: greasy_MJLN0_SA1.WAV with scenes at -3.65 dB SNR
# Processed: greasy_MJTC0_SA1.WAV with babble at -2.93 dB SNR
# Processed: greasy_MJTH0_SA1.WAV with babble at -1.96 dB SNR
# Processed: greasy_MPAM0_SA1.WAV with scenes at -0.77 dB SNR
# Processed: greasy_MRES0_SA1.WAV with scenes at -2.13 dB SNR
# Processed: greasy_MSLB0_SA1.WAV with babble at -5.29 dB SNR
# Processed: greasy_FCJF0_SA1.WAV with babble at -3.16 dB SNR
# Processed: greasy_FDAW0_SA1.WAV with babble at 0.81 dB SNR
# Processed: greasy_FDML0_SA1.WAV with scenes at -1.30 dB SNR
# Processed: greasy_FECD0_SA1.WAV with scenes at -3.54 dB SNR
# Processed: greasy_FETB0_SA1.WAV with babble at -2.72 dB SNR
# Processed: greasy_FJSP0_SA1.WAV with music at -3.28 dB SNR
# Processed: greasy_FKFB0_SA1.WAV with music at -5.40 dB SNR
# Processed: greasy_FMEM0_SA1.WAV with scenes at -3.03 dB SNR
# Processed: greasy_FSAH0_SA1.WAV with music at -7.06 dB SNR
# Processed: greasy_FSJK1_SA1.WAV with babble at -1.57 dB SNR
# Processed: greasy_FSMA0_SA1.WAV with scenes at -4.35 dB SNR
# Processed: greasy_FTBR0_SA1.WAV with scenes at -0.80 dB SNR
# Processed: greasy_FVFB0_SA1.WAV with music at -7.08 dB SNR
# Processed: greasy_FVMH0_SA1.WAV with babble at 0.60 dB SNR
# Processed: greasy_MCPM0_SA1.WAV with babble at -2.79 dB SNR
# Processed: greasy_MDAC0_SA1.WAV with scenes at -6.57 dB SNR
# Processed: greasy_MDPK0_SA1.WAV with scenes at -1.31 dB SNR
# Processed: greasy_MEDR0_SA1.WAV with music at -7.63 dB SNR
# Processed: greasy_MGRL0_SA1.WAV with babble at -2.88 dB SNR
# Processed: greasy_MJEB1_SA1.WAV with babble at -5.75 dB SNR
# Processed: greasy_MJWT0_SA1.WAV with babble at -2.79 dB SNR
# Processed: greasy_MKLS0_SA1.WAV with music at -6.24 dB SNR
# Processed: greasy_MKLW0_SA1.WAV with scenes at -0.43 dB SNR
# Processed: greasy_MMGG0_SA1.WAV with babble at -0.23 dB SNR
# Processed: greasy_MMRP0_SA1.WAV with babble at -1.46 dB SNR
# Processed: greasy_MPGH0_SA1.WAV with music at -6.44 dB SNR
# Processed: greasy_MPGR0_SA1.WAV with babble at -2.13 dB SNR
# Processed: greasy_MPSW0_SA1.WAV with scenes at -0.92 dB SNR
# Processed: greasy_MRAI0_SA1.WAV with music at -5.02 dB SNR
# Processed: greasy_MRCG0_SA1.WAV with music at -0.77 dB SNR
# Processed: greasy_MRDD0_SA1.WAV with music at -10.15 dB SNR
# Processed: greasy_MRSO0_SA1.WAV with scenes at 0.86 dB SNR
# Processed: greasy_MRWS0_SA1.WAV with music at -4.54 dB SNR
# Processed: greasy_MTJS0_SA1.WAV with music at -7.18 dB SNR
# Processed: greasy_MTPF0_SA1.WAV with scenes at -4.10 dB SNR
# Processed: greasy_MTRR0_SA1.WAV with music at -6.77 dB SNR
# Processed: greasy_MWAD0_SA1.WAV with music at -9.22 dB SNR
# Processed: greasy_MWAR0_SA1.WAV with babble at -3.06 dB SNR
# Processed: greasy_FAEM0_SA1.WAV with music at -6.35 dB SNR
# Processed: greasy_FAJW0_SA1.WAV with music at -9.24 dB SNR
# Processed: greasy_FCAJ0_SA1.WAV with music at -6.33 dB SNR
# Processed: greasy_FCMM0_SA1.WAV with music at -7.82 dB SNR
# Processed: greasy_FCYL0_SA1.WAV with music at -8.24 dB SNR
# Processed: greasy_FDAS1_SA1.WAV with babble at -2.78 dB SNR
# Processed: greasy_FDNC0_SA1.WAV with music at -4.90 dB SNR
# Processed: greasy_FDXW0_SA1.WAV with scenes at -5.05 dB SNR
# Processed: greasy_FEAC0_SA1.WAV with babble at 1.26 dB SNR
# Processed: greasy_FHLM0_SA1.WAV with babble at -7.00 dB SNR
# Processed: greasy_FJKL0_SA1.WAV with music at -6.33 dB SNR
# Processed: greasy_FKAA0_SA1.WAV with scenes at -1.83 dB SNR
# Processed: greasy_FLMA0_SA1.WAV with music at -9.06 dB SNR
# Processed: greasy_FLMC0_SA1.WAV with music at -6.70 dB SNR
# Processed: greasy_FMJB0_SA1.WAV with babble at -4.55 dB SNR
# Processed: greasy_FMKF0_SA1.WAV with music at -10.55 dB SNR
# Processed: greasy_FMMH0_SA1.WAV with babble at -4.01 dB SNR
# Processed: greasy_FPJF0_SA1.WAV with music at -6.10 dB SNR
# Processed: greasy_FRLL0_SA1.WAV with scenes at -3.35 dB SNR
# Processed: greasy_FSCN0_SA1.WAV with babble at -1.16 dB SNR
# Processed: greasy_FSKL0_SA1.WAV with babble at -1.43 dB SNR
# Processed: greasy_FSRH0_SA1.WAV with music at -6.75 dB SNR
# Processed: greasy_FTMG0_SA1.WAV with music at -9.87 dB SNR
# Processed: greasy_MARC0_SA1.WAV with music at -5.45 dB SNR
# Processed: greasy_MBJV0_SA1.WAV with scenes at -0.79 dB SNR
# Processed: greasy_MCEW0_SA1.WAV with scenes at -8.93 dB SNR
# Processed: greasy_MCTM0_SA1.WAV with babble at -3.99 dB SNR
# Processed: greasy_MDBP0_SA1.WAV with scenes at -3.97 dB SNR
# Processed: greasy_MDEM0_SA1.WAV with scenes at -2.12 dB SNR
# Processed: greasy_MDLB0_SA1.WAV with music at -7.98 dB SNR
# Processed: greasy_MDLC2_SA1.WAV with music at -1.85 dB SNR
# Processed: greasy_MDMT0_SA1.WAV with scenes at -3.53 dB SNR
# Processed: greasy_MDPS0_SA1.WAV with babble at -0.87 dB SNR
# Processed: greasy_MDSS0_SA1.WAV with babble at -3.97 dB SNR
# Processed: greasy_MDWD0_SA1.WAV with music at -4.06 dB SNR
# Processed: greasy_MEFG0_SA1.WAV with babble at -2.66 dB SNR
# Processed: greasy_MHRM0_SA1.WAV with babble at -3.97 dB SNR
# Processed: greasy_MJAE0_SA1.WAV with music at -7.16 dB SNR
# Processed: greasy_MJBG0_SA1.WAV with music at -4.40 dB SNR
# Processed: greasy_MJDE0_SA1.WAV with babble at -6.75 dB SNR
# Processed: greasy_MJEB0_SA1.WAV with music at -7.91 dB SNR
# Processed: greasy_MJHI0_SA1.WAV with scenes at -5.03 dB SNR
# Processed: greasy_MJMA0_SA1.WAV with scenes at -2.94 dB SNR
# Processed: greasy_MJMD0_SA1.WAV with babble at -5.08 dB SNR
# Processed: greasy_MJPM0_SA1.WAV with babble at -3.07 dB SNR
# Processed: greasy_MJRP0_SA1.WAV with scenes at -4.38 dB SNR
# Processed: greasy_MKAH0_SA1.WAV with music at -3.30 dB SNR
# Processed: greasy_MKAJ0_SA1.WAV with babble at 0.15 dB SNR
# Processed: greasy_MKDT0_SA1.WAV with babble at -2.36 dB SNR
# Processed: greasy_MKJO0_SA1.WAV with babble at -2.08 dB SNR
# Processed: greasy_MMAA0_SA1.WAV with babble at 1.56 dB SNR
# Processed: greasy_MMAG0_SA1.WAV with scenes at -4.36 dB SNR
# Processed: greasy_MMDS0_SA1.WAV with music at -7.54 dB SNR
# Processed: greasy_MMGK0_SA1.WAV with music at -6.74 dB SNR
# Processed: greasy_MMXS0_SA1.WAV with music at -9.25 dB SNR
# Processed: greasy_MPPC0_SA1.WAV with babble at 1.45 dB SNR
# Processed: greasy_MPRB0_SA1.WAV with babble at -0.52 dB SNR
# Processed: greasy_MRAB0_SA1.WAV with scenes at -2.84 dB SNR
# Processed: greasy_MRCW0_SA1.WAV with babble at -3.00 dB SNR
# Processed: greasy_MRFK0_SA1.WAV with babble at -6.72 dB SNR
# Processed: greasy_MRGS0_SA1.WAV with music at -4.27 dB SNR
# Processed: greasy_MRHL0_SA1.WAV with babble at -0.35 dB SNR
# Processed: greasy_MRJH0_SA1.WAV with scenes at -5.27 dB SNR
# Processed: greasy_MRJM0_SA1.WAV with music at -7.07 dB SNR
# Processed: greasy_MRJM1_SA1.WAV with babble at -1.39 dB SNR
# Processed: greasy_MRJT0_SA1.WAV with babble at -0.91 dB SNR
# Processed: greasy_MRLJ0_SA1.WAV with music at -5.79 dB SNR
# Processed: greasy_MRLR0_SA1.WAV with music at -7.73 dB SNR
# Processed: greasy_MRMS0_SA1.WAV with scenes at -4.27 dB SNR
# Processed: greasy_MSAT0_SA1.WAV with music at -4.15 dB SNR
# Processed: greasy_MTAT1_SA1.WAV with babble at -2.72 dB SNR
# Processed: greasy_MTBC0_SA1.WAV with music at -4.25 dB SNR
# Processed: greasy_MTDB0_SA1.WAV with babble at -2.13 dB SNR
# Processed: greasy_MTJG0_SA1.WAV with music at -6.61 dB SNR
# Processed: greasy_MWSB0_SA1.WAV with music at -4.17 dB SNR
# Processed: greasy_MZMB0_SA1.WAV with music at -7.18 dB SNR
# Processed: greasy_FALK0_SA1.WAV with scenes at -3.69 dB SNR
# Processed: greasy_FCKE0_SA1.WAV with babble at -2.06 dB SNR
# Processed: greasy_FCMG0_SA1.WAV with scenes at -3.09 dB SNR
# Processed: greasy_FDFB0_SA1.WAV with scenes at -5.72 dB SNR
# Processed: greasy_FDJH0_SA1.WAV with babble at -3.82 dB SNR
# Processed: greasy_FEME0_SA1.WAV with scenes at -2.95 dB SNR
# Processed: greasy_FGCS0_SA1.WAV with scenes at -3.10 dB SNR
# Processed: greasy_FGRW0_SA1.WAV with music at -4.38 dB SNR
# Processed: greasy_FJLG0_SA1.WAV with babble at -3.42 dB SNR
# Processed: greasy_FJLR0_SA1.WAV with babble at -3.78 dB SNR
# Processed: greasy_FLAC0_SA1.WAV with music at -6.74 dB SNR
# Processed: greasy_FLJD0_SA1.WAV with scenes at -5.78 dB SNR
# Processed: greasy_FLTM0_SA1.WAV with babble at -2.06 dB SNR
# Processed: greasy_FMJF0_SA1.WAV with music at -4.78 dB SNR
# Processed: greasy_FNTB0_SA1.WAV with babble at -4.98 dB SNR
# Processed: greasy_FPAZ0_SA1.WAV with music at -8.02 dB SNR
# Processed: greasy_FSJS0_SA1.WAV with scenes at 0.55 dB SNR
# Processed: greasy_FSJW0_SA1.WAV with music at -4.38 dB SNR
# Processed: greasy_FSKC0_SA1.WAV with babble at -4.85 dB SNR
# Processed: greasy_FSLS0_SA1.WAV with babble at -5.75 dB SNR
# Processed: greasy_MADC0_SA1.WAV with scenes at -5.70 dB SNR
# Processed: greasy_MAKB0_SA1.WAV with scenes at -3.06 dB SNR
# Processed: greasy_MAKR0_SA1.WAV with scenes at -1.12 dB SNR
# Processed: greasy_MAPV0_SA1.WAV with babble at -4.95 dB SNR
# Processed: greasy_MBEF0_SA1.WAV with music at -7.16 dB SNR
# Processed: greasy_MCAL0_SA1.WAV with scenes at -3.61 dB SNR
# Processed: greasy_MCDC0_SA1.WAV with music at -6.28 dB SNR
# Processed: greasy_MCDD0_SA1.WAV with scenes at -1.83 dB SNR
# Processed: greasy_MCEF0_SA1.WAV with music at -8.02 dB SNR
# Processed: greasy_MDBB1_SA1.WAV with music at -1.62 dB SNR
# Processed: greasy_MDDC0_SA1.WAV with music at -9.93 dB SNR
# Processed: greasy_MDEF0_SA1.WAV with music at -7.27 dB SNR
# Processed: greasy_MDHS0_SA1.WAV with scenes at -4.83 dB SNR
# Processed: greasy_MDJM0_SA1.WAV with scenes at -2.42 dB SNR
# Processed: greasy_MDLC0_SA1.WAV with scenes at -0.80 dB SNR
# Processed: greasy_MDLH0_SA1.WAV with music at -7.63 dB SNR
# Processed: greasy_MDNS0_SA1.WAV with babble at -3.78 dB SNR
# Processed: greasy_MDSS1_SA1.WAV with scenes at -4.17 dB SNR
# Processed: greasy_MDTB0_SA1.WAV with babble at -5.87 dB SNR
# Processed: greasy_MDWM0_SA1.WAV with babble at -5.09 dB SNR
# Processed: greasy_MFMC0_SA1.WAV with babble at -2.81 dB SNR
# Processed: greasy_MGAF0_SA1.WAV with babble at -3.19 dB SNR
# Processed: greasy_MHJB0_SA1.WAV with babble at 1.40 dB SNR
# Processed: greasy_MHMR0_SA1.WAV with babble at 0.88 dB SNR
# Processed: greasy_MILB0_SA1.WAV with babble at -2.28 dB SNR
# Processed: greasy_MJDA0_SA1.WAV with babble at -2.38 dB SNR
# Processed: greasy_MJJB0_SA1.WAV with scenes at -4.05 dB SNR
# Processed: greasy_MJKR0_SA1.WAV with scenes at -4.86 dB SNR
# Processed: greasy_MJLG1_SA1.WAV with scenes at -4.45 dB SNR
# Processed: greasy_MJRH1_SA1.WAV with music at -4.76 dB SNR
# Processed: greasy_MKLS1_SA1.WAV with scenes at -3.88 dB SNR
# Processed: greasy_MKXL0_SA1.WAV with scenes at -3.99 dB SNR
# Processed: greasy_MLNS0_SA1.WAV with babble at -1.03 dB SNR
# Processed: greasy_MMAM0_SA1.WAV with scenes at -2.19 dB SNR
# Processed: greasy_MMAR0_SA1.WAV with scenes at -1.39 dB SNR
# Processed: greasy_MMEB0_SA1.WAV with music at -4.60 dB SNR
# Processed: greasy_MMJB1_SA1.WAV with scenes at -2.31 dB SNR
# Processed: greasy_MMSM0_SA1.WAV with music at -6.83 dB SNR
# Processed: greasy_MPRD0_SA1.WAV with music at -7.47 dB SNR
# Processed: greasy_MRBC0_SA1.WAV with music at -2.33 dB SNR
# Processed: greasy_MRDS0_SA1.WAV with scenes at -2.74 dB SNR
# Processed: greasy_MREE0_SA1.WAV with scenes at -3.79 dB SNR
# Processed: greasy_MREH1_SA1.WAV with babble at -3.23 dB SNR
# Processed: greasy_MRJB1_SA1.WAV with scenes at -4.22 dB SNR
# Processed: greasy_MRTC0_SA1.WAV with scenes at -1.82 dB SNR
# Processed: greasy_MRTJ0_SA1.WAV with babble at -1.59 dB SNR
# Processed: greasy_MRWA0_SA1.WAV with music at -9.46 dB SNR
# Processed: greasy_MSFV0_SA1.WAV with babble at -3.75 dB SNR
# Processed: greasy_MTJM0_SA1.WAV with music at -5.22 dB SNR
# Processed: greasy_MTKP0_SA1.WAV with scenes at -2.98 dB SNR
# Processed: greasy_MTLB0_SA1.WAV with babble at -2.87 dB SNR
# Processed: greasy_MTPG0_SA1.WAV with music at -8.35 dB SNR
# Processed: greasy_MTPP0_SA1.WAV with scenes at -2.14 dB SNR
# Processed: greasy_MVJH0_SA1.WAV with scenes at -5.09 dB SNR
# Processed: greasy_MWDK0_SA1.WAV with babble at -6.32 dB SNR
# Processed: greasy_MWGR0_SA1.WAV with music at -3.80 dB SNR
# Processed: greasy_FALR0_SA1.WAV with babble at -3.06 dB SNR
# Processed: greasy_FBAS0_SA1.WAV with scenes at -0.05 dB SNR
# Processed: greasy_FBMJ0_SA1.WAV with scenes at -1.10 dB SNR
# Processed: greasy_FCAG0_SA1.WAV with babble at -4.57 dB SNR
# Processed: greasy_FDKN0_SA1.WAV with babble at -1.89 dB SNR
# Processed: greasy_FEEH0_SA1.WAV with scenes at -6.86 dB SNR
# Processed: greasy_FJWB1_SA1.WAV with scenes at -0.61 dB SNR
# Processed: greasy_FJXP0_SA1.WAV with babble at -1.65 dB SNR
# Processed: greasy_FKDW0_SA1.WAV with scenes at -1.85 dB SNR
# Processed: greasy_FKLC0_SA1.WAV with music at -5.28 dB SNR
# Processed: greasy_FLHD0_SA1.WAV with babble at -2.91 dB SNR
# Processed: greasy_FLKM0_SA1.WAV with scenes at -5.17 dB SNR
# Processed: greasy_FPAF0_SA1.WAV with music at -5.60 dB SNR
# Processed: greasy_FSAK0_SA1.WAV with scenes at -3.00 dB SNR
# Processed: greasy_FSSB0_SA1.WAV with scenes at -1.78 dB SNR
# Processed: greasy_MAEB0_SA1.WAV with babble at -6.02 dB SNR
# Processed: greasy_MARW0_SA1.WAV with music at -7.86 dB SNR
# Processed: greasy_MBMA0_SA1.WAV with music at -10.39 dB SNR
# Processed: greasy_MBWP0_SA1.WAV with babble at -1.37 dB SNR
# Processed: greasy_MCDR0_SA1.WAV with music at -10.27 dB SNR
# Processed: greasy_MCSS0_SA1.WAV with babble at -5.05 dB SNR
# Processed: greasy_MDCD0_SA1.WAV with scenes at -1.90 dB SNR
# Processed: greasy_MDMA0_SA1.WAV with scenes at -1.18 dB SNR
# Processed: greasy_MESG0_SA1.WAV with babble at -3.50 dB SNR
# Processed: greasy_MFRM0_SA1.WAV with babble at -4.95 dB SNR
# Processed: greasy_MFWK0_SA1.WAV with babble at -4.38 dB SNR
# Processed: greasy_MGAG0_SA1.WAV with scenes at -1.35 dB SNR
# Processed: greasy_MGJC0_SA1.WAV with scenes at -0.90 dB SNR
# Processed: greasy_MGRP0_SA1.WAV with scenes at -5.05 dB SNR
# Processed: greasy_MGXP0_SA1.WAV with scenes at -4.28 dB SNR
# Processed: greasy_MJAC0_SA1.WAV with scenes at -4.20 dB SNR
# Processed: greasy_MJDC0_SA1.WAV with scenes at -5.06 dB SNR
# Processed: greasy_MJEE0_SA1.WAV with music at -3.80 dB SNR
# Processed: greasy_MJJJ0_SA1.WAV with babble at -2.12 dB SNR
# Processed: greasy_MJLB0_SA1.WAV with scenes at -2.40 dB SNR
# Processed: greasy_MJLS0_SA1.WAV with babble at 0.15 dB SNR
# Processed: greasy_MJMM0_SA1.WAV with music at -5.51 dB SNR
# Processed: greasy_MJPM1_SA1.WAV with music at -7.57 dB SNR
# Processed: greasy_MJRH0_SA1.WAV with scenes at -5.99 dB SNR
# Processed: greasy_MJSR0_SA1.WAV with scenes at -2.70 dB SNR
# Processed: greasy_MJWS0_SA1.WAV with music at -3.26 dB SNR
# Processed: greasy_MJXL0_SA1.WAV with music at -5.82 dB SNR
# Processed: greasy_MKAM0_SA1.WAV with scenes at -3.19 dB SNR
# Processed: greasy_MLBC0_SA1.WAV with scenes at -4.59 dB SNR
# Processed: greasy_MLEL0_SA1.WAV with scenes at -1.88 dB SNR
# Processed: greasy_MLJC0_SA1.WAV with music at -5.30 dB SNR
# Processed: greasy_MLJH0_SA1.WAV with music at -4.45 dB SNR
# Processed: greasy_MLSH0_SA1.WAV with babble at -2.17 dB SNR
# Processed: greasy_MMBS0_SA1.WAV with babble at -7.12 dB SNR
# Processed: greasy_MMDM0_SA1.WAV with babble at -2.04 dB SNR
# Processed: greasy_MMGC0_SA1.WAV with babble at -0.08 dB SNR
# Processed: greasy_MNET0_SA1.WAV with music at -8.58 dB SNR
# Processed: greasy_MPEB0_SA1.WAV with scenes at -1.88 dB SNR
# Processed: greasy_MPRK0_SA1.WAV with scenes at -3.46 dB SNR
# Processed: greasy_MPRT0_SA1.WAV with babble at -4.16 dB SNR
# Processed: greasy_MRAB1_SA1.WAV with babble at -4.27 dB SNR
# Processed: greasy_MRFL0_SA1.WAV with scenes at -3.66 dB SNR
# Processed: greasy_MRGM0_SA1.WAV with babble at -0.22 dB SNR
# Processed: greasy_MRSP0_SA1.WAV with music at -8.61 dB SNR
# Processed: greasy_MSFH0_SA1.WAV with babble at -0.10 dB SNR
# Processed: greasy_MSMC0_SA1.WAV with scenes at -3.58 dB SNR
# Processed: greasy_MSMS0_SA1.WAV with scenes at -3.76 dB SNR
# Processed: greasy_MSRG0_SA1.WAV with scenes at -1.11 dB SNR
# Processed: greasy_MSTF0_SA1.WAV with scenes at -2.93 dB SNR
# Processed: greasy_MTAS0_SA1.WAV with music at -7.57 dB SNR
# Processed: greasy_MTQC0_SA1.WAV with music at -6.08 dB SNR
# Processed: greasy_MTRC0_SA1.WAV with music at -8.60 dB SNR
# Processed: greasy_MTRT0_SA1.WAV with scenes at -3.64 dB SNR
# Processed: greasy_FBJL0_SA1.WAV with scenes at 1.27 dB SNR
# Processed: greasy_FBMH0_SA1.WAV with scenes at -1.26 dB SNR
# Processed: greasy_FCDR1_SA1.WAV with babble at 0.15 dB SNR
# Processed: greasy_FDMY0_SA1.WAV with scenes at -3.55 dB SNR
# Processed: greasy_FDTD0_SA1.WAV with scenes at -3.49 dB SNR
# Processed: greasy_FEAR0_SA1.WAV with music at -4.27 dB SNR
# Processed: greasy_FEXM0_SA1.WAV with scenes at -5.25 dB SNR
# Processed: greasy_FGDP0_SA1.WAV with scenes at -3.29 dB SNR
# Processed: greasy_FGMB0_SA1.WAV with babble at -4.51 dB SNR
# Processed: greasy_FJXM0_SA1.WAV with scenes at -3.10 dB SNR
# Processed: greasy_FKKH0_SA1.WAV with babble at -3.42 dB SNR
# Processed: greasy_FLJA0_SA1.WAV with scenes at -2.75 dB SNR
# Processed: greasy_FLJG0_SA1.WAV with scenes at -6.13 dB SNR
# Processed: greasy_FLMK0_SA1.WAV with babble at -4.22 dB SNR
# Processed: greasy_FLOD0_SA1.WAV with babble at -2.46 dB SNR
# Processed: greasy_FMPG0_SA1.WAV with babble at -2.77 dB SNR
# Processed: greasy_FPMY0_SA1.WAV with scenes at -3.27 dB SNR
# Processed: greasy_FSAG0_SA1.WAV with scenes at -4.35 dB SNR
# Processed: greasy_FSDC0_SA1.WAV with scenes at -1.81 dB SNR
# Processed: greasy_FSJG0_SA1.WAV with babble at -6.44 dB SNR
# Processed: greasy_FSKP0_SA1.WAV with babble at -4.31 dB SNR
# Processed: greasy_FSMM0_SA1.WAV with music at -8.13 dB SNR
# Processed: greasy_FSMS1_SA1.WAV with music at -7.43 dB SNR
# Processed: greasy_FTBW0_SA1.WAV with music at -5.88 dB SNR
# Processed: greasy_FTLG0_SA1.WAV with scenes at -1.91 dB SNR
# Processed: greasy_MBGT0_SA1.WAV with music at -6.64 dB SNR
# Processed: greasy_MCHL0_SA1.WAV with scenes at -7.21 dB SNR
# Processed: greasy_MCLM0_SA1.WAV with music at -1.80 dB SNR
# Processed: greasy_MDAS0_SA1.WAV with scenes at -1.97 dB SNR
# Processed: greasy_MDHL0_SA1.WAV with scenes at -3.23 dB SNR
# Processed: greasy_MDSJ0_SA1.WAV with music at -1.54 dB SNR
# Processed: greasy_MDWH0_SA1.WAV with babble at -1.20 dB SNR
# Processed: greasy_MEGJ0_SA1.WAV with scenes at -1.25 dB SNR
# Processed: greasy_MEWM0_SA1.WAV with scenes at 1.10 dB SNR
# Processed: greasy_MFER0_SA1.WAV with scenes at -2.79 dB SNR
# Processed: greasy_MGES0_SA1.WAV with scenes at -0.59 dB SNR
# Processed: greasy_MGSH0_SA1.WAV with babble at -1.15 dB SNR
# Processed: greasy_MHIT0_SA1.WAV with music at -3.53 dB SNR
# Processed: greasy_MHMG0_SA1.WAV with babble at -5.44 dB SNR
# Processed: greasy_MJDM0_SA1.WAV with babble at 0.01 dB SNR
# Processed: greasy_MJFH0_SA1.WAV with babble at -2.09 dB SNR
# Processed: greasy_MJPG0_SA1.WAV with babble at -1.43 dB SNR
# Processed: greasy_MJRG0_SA1.WAV with music at -8.16 dB SNR
# Processed: greasy_MJWG0_SA1.WAV with music at -10.66 dB SNR
# Processed: greasy_MJXA0_SA1.WAV with music at -7.61 dB SNR
# Processed: greasy_MMAB1_SA1.WAV with babble at 2.47 dB SNR
# Processed: greasy_MMCC0_SA1.WAV with music at -4.97 dB SNR
# Processed: greasy_MMDM1_SA1.WAV with music at -7.73 dB SNR
# Processed: greasy_MMVP0_SA1.WAV with babble at -2.47 dB SNR
# Processed: greasy_MMWB0_SA1.WAV with scenes at -2.98 dB SNR
# Processed: greasy_MPMB0_SA1.WAV with music at -0.95 dB SNR
# Processed: greasy_MRAM0_SA1.WAV with music at -10.13 dB SNR
# Processed: greasy_MRAV0_SA1.WAV with scenes at 0.86 dB SNR
# Processed: greasy_MREW1_SA1.WAV with scenes at -3.70 dB SNR
# Processed: greasy_MRKM0_SA1.WAV with music at -7.19 dB SNR
# Processed: greasy_MRLD0_SA1.WAV with music at -3.53 dB SNR
# Processed: greasy_MRML0_SA1.WAV with scenes at -6.35 dB SNR
# Processed: greasy_MRVG0_SA1.WAV with babble at -2.47 dB SNR
# Processed: greasy_MSAS0_SA1.WAV with babble at -3.50 dB SNR
# Processed: greasy_MSDH0_SA1.WAV with babble at -3.49 dB SNR
# Processed: greasy_MSEM1_SA1.WAV with scenes at -2.78 dB SNR
# Processed: greasy_MSRR0_SA1.WAV with babble at -4.67 dB SNR
# Processed: greasy_MTAT0_SA1.WAV with music at -8.86 dB SNR
# Processed: greasy_MTDP0_SA1.WAV with music at -8.08 dB SNR
# Processed: greasy_MTMT0_SA1.WAV with scenes at -5.19 dB SNR
# Processed: greasy_MVLO0_SA1.WAV with babble at -6.89 dB SNR
# Processed: greasy_MWAC0_SA1.WAV with scenes at -2.49 dB SNR
# Processed: greasy_MWCH0_SA1.WAV with scenes at -0.81 dB SNR
# Processed: greasy_MWEM0_SA1.WAV with music at -2.32 dB SNR
# Processed: greasy_MWSH0_SA1.WAV with music at -8.13 dB SNR
# Processed: greasy_FAPB0_SA1.WAV with babble at -2.38 dB SNR
# Processed: greasy_FBCH0_SA1.WAV with babble at -2.25 dB SNR
# Processed: greasy_FHXS0_SA1.WAV with scenes at -1.38 dB SNR
# Processed: greasy_FJDM2_SA1.WAV with scenes at -0.98 dB SNR
# Processed: greasy_FKLC1_SA1.WAV with music at -3.64 dB SNR
# Processed: greasy_FLAG0_SA1.WAV with music at -8.01 dB SNR
# Processed: greasy_FMJU0_SA1.WAV with music at -7.33 dB SNR
# Processed: greasy_FPAD0_SA1.WAV with music at -6.66 dB SNR
# Processed: greasy_FRJB0_SA1.WAV with scenes at -2.23 dB SNR
# Processed: greasy_FSBK0_SA1.WAV with scenes at -0.18 dB SNR
# Processed: greasy_FSDJ0_SA1.WAV with babble at 1.69 dB SNR
# Processed: greasy_FSGF0_SA1.WAV with music at -8.88 dB SNR
# Processed: greasy_FTAJ0_SA1.WAV with music at -7.79 dB SNR
# Processed: greasy_MABC0_SA1.WAV with scenes at -3.42 dB SNR
# Processed: greasy_MAJP0_SA1.WAV with music at -8.79 dB SNR
# Processed: greasy_MBMA1_SA1.WAV with babble at -3.24 dB SNR
# Processed: greasy_MCAE0_SA1.WAV with scenes at -1.14 dB SNR
# Processed: greasy_MDRD0_SA1.WAV with music at -2.31 dB SNR
# Processed: greasy_MEAL0_SA1.WAV with babble at -4.63 dB SNR
# Processed: greasy_MEJL0_SA1.WAV with babble at -5.25 dB SNR
# Processed: greasy_MESJ0_SA1.WAV with scenes at -5.63 dB SNR
# Processed: greasy_MJRK0_SA1.WAV with music at -2.56 dB SNR
# Processed: greasy_MKES0_SA1.WAV with music at -5.35 dB SNR
# Processed: greasy_MKLN0_SA1.WAV with babble at -3.10 dB SNR
# Processed: greasy_MMDB0_SA1.WAV with music at -6.75 dB SNR
# Processed: greasy_MPGR1_SA1.WAV with babble at -3.17 dB SNR
# Processed: greasy_MRMB0_SA1.WAV with babble at -4.11 dB SNR
# Processed: greasy_MRXB0_SA1.WAV with music at -3.09 dB SNR
# Processed: greasy_MSAT1_SA1.WAV with music at -4.75 dB SNR
# Processed: greasy_MSDS0_SA1.WAV with scenes at -0.63 dB SNR
# Processed: greasy_MSJK0_SA1.WAV with babble at -4.54 dB SNR
# Processed: greasy_MSMR0_SA1.WAV with music at -4.63 dB SNR
# Processed: greasy_MSVS0_SA1.WAV with scenes at -1.13 dB SNR
# Processed: greasy_MTJU0_SA1.WAV with babble at -3.76 dB SNR
# Processed: greasy_MTXS0_SA1.WAV with scenes at -4.35 dB SNR
# Processed: greasy_FBLV0_SA1.WAV with music at -4.72 dB SNR
# Processed: greasy_FCJS0_SA1.WAV with music at -6.75 dB SNR
# Processed: greasy_FCRZ0_SA1.WAV with music at -6.75 dB SNR
# Processed: greasy_FJEN0_SA1.WAV with music at -5.34 dB SNR
# Processed: greasy_FJHK0_SA1.WAV with babble at 0.73 dB SNR
# Processed: greasy_FJRP1_SA1.WAV with scenes at -2.97 dB SNR
# Processed: greasy_FJSK0_SA1.WAV with music at -7.80 dB SNR
# Processed: greasy_FKDE0_SA1.WAV with music at -5.87 dB SNR
# Processed: greasy_FKSR0_SA1.WAV with scenes at -4.88 dB SNR
# Processed: greasy_FLEH0_SA1.WAV with scenes at -2.99 dB SNR
# Processed: greasy_FLET0_SA1.WAV with babble at -2.92 dB SNR
# Processed: greasy_FMAH1_SA1.WAV with babble at -3.42 dB SNR
# Processed: greasy_FMKC0_SA1.WAV with babble at -7.02 dB SNR
# Processed: greasy_FPAB1_SA1.WAV with scenes at -3.90 dB SNR
# Processed: greasy_FPAC0_SA1.WAV with babble at -5.50 dB SNR
# Processed: greasy_FREH0_SA1.WAV with music at -4.64 dB SNR
# Processed: greasy_FSPM0_SA1.WAV with scenes at -4.79 dB SNR
# Processed: greasy_FVKB0_SA1.WAV with scenes at -1.21 dB SNR
# Processed: greasy_MADD0_SA1.WAV with music at -6.50 dB SNR
# Processed: greasy_MAEO0_SA1.WAV with babble at -1.05 dB SNR
# Processed: greasy_MAFM0_SA1.WAV with scenes at -2.02 dB SNR
# Processed: greasy_MBAR0_SA1.WAV with music at -4.75 dB SNR
# Processed: greasy_MBBR0_SA1.WAV with scenes at -3.74 dB SNR
# Processed: greasy_MBML0_SA1.WAV with music at -8.88 dB SNR
# Processed: greasy_MBOM0_SA1.WAV with scenes at -1.50 dB SNR
# Processed: greasy_MBTH0_SA1.WAV with babble at -1.42 dB SNR
# Processed: greasy_MCLK0_SA1.WAV with scenes at -1.96 dB SNR
# Processed: greasy_MCRE0_SA1.WAV with babble at -1.08 dB SNR
# Processed: greasy_MCTH0_SA1.WAV with music at -4.55 dB SNR
# Processed: greasy_MDCM0_SA1.WAV with scenes at -2.74 dB SNR
# Processed: greasy_MDED0_SA1.WAV with music at -10.23 dB SNR
# Processed: greasy_MDKS0_SA1.WAV with babble at -7.17 dB SNR
# Processed: greasy_MDLC1_SA1.WAV with babble at -3.12 dB SNR
# Processed: greasy_MDLM0_SA1.WAV with music at -3.58 dB SNR
# Processed: greasy_MDLR0_SA1.WAV with music at -3.93 dB SNR
# Processed: greasy_MDLR1_SA1.WAV with babble at -3.97 dB SNR
# Processed: greasy_MDPB0_SA1.WAV with babble at -2.27 dB SNR
# Processed: greasy_MFXS0_SA1.WAV with babble at -2.52 dB SNR
# Processed: greasy_MFXV0_SA1.WAV with music at -7.72 dB SNR
# Processed: greasy_MGAK0_SA1.WAV with music at -4.83 dB SNR
# Processed: greasy_MGAR0_SA1.WAV with scenes at -4.75 dB SNR
# Processed: greasy_MGAW0_SA1.WAV with scenes at -1.93 dB SNR
# Processed: greasy_MGSL0_SA1.WAV with music at -7.75 dB SNR
# Processed: greasy_MHBS0_SA1.WAV with scenes at -3.25 dB SNR
# Processed: greasy_MHXL0_SA1.WAV with music at -5.17 dB SNR
# Processed: greasy_MJAI0_SA1.WAV with music at -8.46 dB SNR
# Processed: greasy_MJDG0_SA1.WAV with babble at -4.23 dB SNR
# Processed: greasy_MJFR0_SA1.WAV with music at -8.17 dB SNR
# Processed: greasy_MJJM0_SA1.WAV with music at -4.53 dB SNR
# Processed: greasy_MJRA0_SA1.WAV with babble at -3.37 dB SNR
# Processed: greasy_MKAG0_SA1.WAV with babble at -0.97 dB SNR
# Processed: greasy_MKDB0_SA1.WAV with music at -7.83 dB SNR
# Processed: greasy_MKLR0_SA1.WAV with babble at -3.40 dB SNR
# Processed: greasy_MMDG0_SA1.WAV with babble at -0.36 dB SNR
# Processed: greasy_MMWS1_SA1.WAV with scenes at -3.64 dB SNR
# Processed: greasy_MNTW0_SA1.WAV with music at -8.90 dB SNR
# Processed: greasy_MPAR0_SA1.WAV with scenes at -4.20 dB SNR
# Processed: greasy_MPFU0_SA1.WAV with scenes at -1.02 dB SNR
# Processed: greasy_MREM0_SA1.WAV with babble at -2.49 dB SNR
# Processed: greasy_MRLJ1_SA1.WAV with music at -9.78 dB SNR
# Processed: greasy_MRMG0_SA1.WAV with scenes at -0.10 dB SNR
# Processed: greasy_MRMH0_SA1.WAV with music at -5.53 dB SNR
# Processed: greasy_MRPC1_SA1.WAV with babble at -1.94 dB SNR
# Processed: greasy_MSAH1_SA1.WAV with scenes at -3.02 dB SNR
# Processed: greasy_MSDB0_SA1.WAV with scenes at -3.57 dB SNR
# Processed: greasy_MSES0_SA1.WAV with music at -3.12 dB SNR
# Processed: greasy_MTAB0_SA1.WAV with babble at -4.94 dB SNR
# Processed: greasy_MTER0_SA1.WAV with babble at -0.46 dB SNR
# Processed: greasy_MTKD0_SA1.WAV with babble at -0.15 dB SNR
# Processed: greasy_MTLC0_SA1.WAV with scenes at -1.38 dB SNR
# Processed: greasy_MTML0_SA1.WAV with scenes at -6.30 dB SNR
# Processed: greasy_MTMN0_SA1.WAV with scenes at -5.03 dB SNR
# Processed: greasy_MTPR0_SA1.WAV with music at -4.00 dB SNR
# Processed: greasy_MTWH1_SA1.WAV with scenes at -3.40 dB SNR
# Processed: greasy_MVRW0_SA1.WAV with scenes at -1.09 dB SNR
# Processed: greasy_MWRE0_SA1.WAV with music at -6.19 dB SNR
# Processed: greasy_MWRP0_SA1.WAV with scenes at -1.49 dB SNR
# Processed: greasy_FBCG1_SA1.WAV with babble at -3.30 dB SNR
# Processed: greasy_FCEG0_SA1.WAV with music at -5.88 dB SNR
# Processed: greasy_FCLT0_SA1.WAV with music at -6.42 dB SNR
# Processed: greasy_FJRB0_SA1.WAV with babble at -3.38 dB SNR
# Processed: greasy_FKLH0_SA1.WAV with music at -7.24 dB SNR
# Processed: greasy_FMBG0_SA1.WAV with scenes at -0.12 dB SNR
# Processed: greasy_FNKL0_SA1.WAV with music at -7.68 dB SNR
# Processed: greasy_FPLS0_SA1.WAV with babble at 0.70 dB SNR
# Processed: greasy_MBCG0_SA1.WAV with scenes at -5.59 dB SNR
# Processed: greasy_MBSB0_SA1.WAV with babble at -0.93 dB SNR
# Processed: greasy_MCXM0_SA1.WAV with babble at -2.19 dB SNR
# Processed: greasy_MEJS0_SA1.WAV with scenes at -4.07 dB SNR
# Processed: greasy_MKDD0_SA1.WAV with scenes at -2.07 dB SNR
# Processed: greasy_MKRG0_SA1.WAV with babble at -5.89 dB SNR
# Processed: greasy_MMEA0_SA1.WAV with scenes at -2.93 dB SNR
# Processed: greasy_MMLM0_SA1.WAV with music at -4.87 dB SNR
# Processed: greasy_MMPM0_SA1.WAV with scenes at -4.21 dB SNR
# Processed: greasy_MMWS0_SA1.WAV with music at -3.98 dB SNR
# Processed: greasy_MRDM0_SA1.WAV with music at -3.88 dB SNR
# Processed: greasy_MRLK0_SA1.WAV with music at -8.83 dB SNR
# Processed: greasy_MRRE0_SA1.WAV with scenes at -4.51 dB SNR
# Processed: greasy_MTCS0_SA1.WAV with music at -8.21 dB SNR
# Processed: water_FAKS0_SA1.WAV with babble at -0.90 dB SNR
# Processed: water_FDAC1_SA1.WAV with music at -5.74 dB SNR
# Processed: water_FELC0_SA1.WAV with scenes at -4.19 dB SNR
# Processed: water_FJEM0_SA1.WAV with scenes at -5.67 dB SNR
# Processed: water_MDAB0_SA1.WAV with babble at -4.64 dB SNR
# Processed: water_MJSW0_SA1.WAV with babble at -1.02 dB SNR
# Processed: water_MREB0_SA1.WAV with music at -5.83 dB SNR
# Processed: water_MRJO0_SA1.WAV with babble at -4.36 dB SNR
# Processed: water_MSJS1_SA1.WAV with babble at -7.18 dB SNR
# Processed: water_MSTK0_SA1.WAV with scenes at -2.28 dB SNR
# Processed: water_MWBT0_SA1.WAV with music at -5.04 dB SNR
# Processed: water_FCMR0_SA1.WAV with scenes at -8.32 dB SNR
# Processed: water_FDRD1_SA1.WAV with babble at -0.90 dB SNR
# Processed: water_FJAS0_SA1.WAV with music at -2.92 dB SNR
# Processed: water_FJRE0_SA1.WAV with music at -5.70 dB SNR
# Processed: water_FJWB0_SA1.WAV with babble at -1.26 dB SNR
# Processed: water_FPAS0_SA1.WAV with babble at -1.70 dB SNR
# Processed: water_FRAM1_SA1.WAV with babble at -1.13 dB SNR
# Processed: water_FSLB1_SA1.WAV with scenes at 0.95 dB SNR
# Processed: water_MABW0_SA1.WAV with scenes at -4.89 dB SNR
# Processed: water_MBJK0_SA1.WAV with babble at -1.94 dB SNR
# Processed: water_MCCS0_SA1.WAV with scenes at -1.45 dB SNR
# Processed: water_MCEM0_SA1.WAV with babble at -1.89 dB SNR
# Processed: water_MDBB0_SA1.WAV with scenes at -0.87 dB SNR
# Processed: water_MDLD0_SA1.WAV with music at -4.23 dB SNR
# Processed: water_MGWT0_SA1.WAV with music at -5.29 dB SNR
# Processed: water_MJAR0_SA1.WAV with babble at -3.77 dB SNR
# Processed: water_MMDB1_SA1.WAV with scenes at -1.86 dB SNR
# Processed: water_MMDM2_SA1.WAV with scenes at -3.45 dB SNR
# Processed: water_MPDF0_SA1.WAV with music at -2.10 dB SNR
# Processed: water_MPGL0_SA1.WAV with music at -2.26 dB SNR
# Processed: water_MRCZ0_SA1.WAV with music at -3.89 dB SNR
# Processed: water_MRGG0_SA1.WAV with scenes at -5.28 dB SNR
# Processed: water_MTAS1_SA1.WAV with babble at -3.82 dB SNR
# Processed: water_MTMR0_SA1.WAV with scenes at -3.37 dB SNR
# Processed: water_MWEW0_SA1.WAV with scenes at -1.74 dB SNR
# Processed: water_MWVW0_SA1.WAV with music at -3.64 dB SNR
# Processed: water_FCMH0_SA1.WAV with music at -6.21 dB SNR
# Processed: water_FKMS0_SA1.WAV with scenes at -4.67 dB SNR
# Processed: water_FPKT0_SA1.WAV with scenes at -3.23 dB SNR
# Processed: water_MBDG0_SA1.WAV with babble at -2.22 dB SNR
# Processed: water_MBWM0_SA1.WAV with babble at -0.26 dB SNR
# Processed: water_MCSH0_SA1.WAV with scenes at -5.76 dB SNR
# Processed: water_MCTW0_SA1.WAV with babble at -5.62 dB SNR
# Processed: water_MGJF0_SA1.WAV with babble at -7.48 dB SNR
# Processed: water_MGLB0_SA1.WAV with babble at -5.10 dB SNR
# Processed: water_MHPG0_SA1.WAV with scenes at -1.04 dB SNR
# Processed: water_MJBR0_SA1.WAV with music at -8.07 dB SNR
# Processed: water_MJES0_SA1.WAV with babble at -2.13 dB SNR
# Processed: water_MJJG0_SA1.WAV with babble at -3.18 dB SNR
# Processed: water_MJMP0_SA1.WAV with scenes at -6.71 dB SNR
# Processed: water_MJVW0_SA1.WAV with babble at -3.20 dB SNR
# Processed: water_MKCH0_SA1.WAV with scenes at -3.55 dB SNR
# Processed: water_MLNT0_SA1.WAV with music at -4.49 dB SNR
# Processed: water_MMAB0_SA1.WAV with babble at -1.32 dB SNR
# Processed: water_MMDH0_SA1.WAV with music at -4.89 dB SNR
# Processed: water_MMJR0_SA1.WAV with babble at -5.22 dB SNR
# Processed: water_MMWH0_SA1.WAV with babble at -0.06 dB SNR
# Processed: water_MRTK0_SA1.WAV with music at -3.37 dB SNR
# Processed: water_MTAA0_SA1.WAV with babble at -6.18 dB SNR
# Processed: water_MTDT0_SA1.WAV with music at -8.22 dB SNR
# Processed: water_MTHC0_SA1.WAV with music at -4.17 dB SNR
# Processed: water_MWJG0_SA1.WAV with music at -4.79 dB SNR
# Processed: water_FADG0_SA1.WAV with music at -4.49 dB SNR
# Processed: water_FCFT0_SA1.WAV with babble at 0.06 dB SNR
# Processed: water_FCRH0_SA1.WAV with babble at -1.27 dB SNR
# Processed: water_FDMS0_SA1.WAV with scenes at -3.64 dB SNR
# Processed: water_FEDW0_SA1.WAV with music at -9.44 dB SNR
# Processed: water_FGJD0_SA1.WAV with scenes at -3.56 dB SNR
# Processed: water_FJLM0_SA1.WAV with music at -5.46 dB SNR
# Processed: water_FJMG0_SA1.WAV with babble at -0.92 dB SNR
# Processed: water_FJMG0_SI1811.WAV with music at -2.78 dB SNR
# Processed: water_FLBW0_SA1.WAV with babble at -4.82 dB SNR
# Processed: water_FLKD0_SA1.WAV with music at -8.86 dB SNR
# Processed: water_FMAF0_SA1.WAV with music at -6.65 dB SNR
# Processed: water_FMCM0_SA1.WAV with scenes at -1.99 dB SNR
# Processed: water_FNMR0_SA1.WAV with scenes at -3.52 dB SNR
# Processed: water_FREW0_SA1.WAV with babble at -7.15 dB SNR
# Processed: water_FRNG0_SA1.WAV with babble at -5.20 dB SNR
# Processed: water_FSEM0_SA1.WAV with scenes at -2.74 dB SNR
# Processed: water_MBNS0_SA1.WAV with music at -10.91 dB SNR
# Processed: water_MDLS0_SA1.WAV with scenes at -3.53 dB SNR
# Processed: water_MDRM0_SA1.WAV with babble at -1.96 dB SNR
# Processed: water_MGMM0_SA1.WAV with music at -8.12 dB SNR
# Processed: water_MJDM1_SA1.WAV with scenes at -10.02 dB SNR
# Processed: water_MJRF0_SA1.WAV with scenes at -1.59 dB SNR
# Processed: water_MKCL0_SA1.WAV with music at -6.38 dB SNR
# Processed: water_MLJB0_SA1.WAV with music at -8.75 dB SNR
# Processed: water_MLLL0_SA1.WAV with babble at -2.76 dB SNR
# Processed: water_MPCS0_SA1.WAV with music at -4.04 dB SNR
# Processed: water_MPLB0_SA1.WAV with scenes at -3.60 dB SNR
# Processed: water_MPWM0_SA1.WAV with scenes at -1.82 dB SNR
# Processed: water_MRKO0_SA1.WAV with music at -6.47 dB SNR
# Processed: water_MROA0_SA1.WAV with babble at -3.01 dB SNR
# Processed: water_MTEB0_SA1.WAV with scenes at -5.36 dB SNR
# Processed: water_MTLS0_SA1.WAV with babble at -0.41 dB SNR
# Processed: water_FASW0_SA1.WAV with babble at -2.77 dB SNR
# Processed: water_FASW0_SI2180.WAV with scenes at -3.27 dB SNR
# Processed: water_FAWF0_SA1.WAV with music at -2.60 dB SNR
# Processed: water_FCAL1_SA1.WAV with scenes at -1.39 dB SNR
# Processed: water_FGMD0_SA1.WAV with babble at -3.53 dB SNR
# Processed: water_FHES0_SA1.WAV with babble at -6.06 dB SNR
# Processed: water_FHEW0_SA1.WAV with scenes at -3.98 dB SNR
# Processed: water_FJCS0_SA1.WAV with scenes at -4.63 dB SNR
# Processed: water_FJSA0_SA1.WAV with babble at -1.25 dB SNR
# Processed: water_FMAH0_SA1.WAV with babble at -3.89 dB SNR
# Processed: water_FNLP0_SA1.WAV with music at -6.87 dB SNR
# Processed: water_FUTB0_SA1.WAV with babble at -4.62 dB SNR
# Processed: water_MAHH0_SA1.WAV with scenes at -3.01 dB SNR
# Processed: water_MBPM0_SA1.WAV with scenes at -5.09 dB SNR
# Processed: water_MCMB0_SA1.WAV with music at -3.04 dB SNR
# Processed: water_MCRC0_SA1.WAV with music at -5.97 dB SNR
# Processed: water_MCTT0_SA1.WAV with music at -7.54 dB SNR
# Processed: water_MDAC2_SA1.WAV with music at -5.16 dB SNR
# Processed: water_MDRB0_SA1.WAV with babble at -1.16 dB SNR
# Processed: water_MDWA0_SA1.WAV with scenes at -4.02 dB SNR
# Processed: water_MDWK0_SA1.WAV with babble at -0.85 dB SNR
# Processed: water_MFGK0_SA1.WAV with scenes at -4.44 dB SNR
# Processed: water_MKLT0_SA1.WAV with scenes at -2.04 dB SNR
# Processed: water_MLIH0_SA1.WAV with babble at -2.36 dB SNR
# Processed: water_MRJM3_SA1.WAV with music at -4.69 dB SNR
# Processed: water_MRPP0_SA1.WAV with music at -5.81 dB SNR
# Processed: water_MRRK0_SA1.WAV with babble at -0.91 dB SNR
# Processed: water_MRWS1_SA1.WAV with babble at -2.78 dB SNR
# Processed: water_MSFH1_SA1.WAV with music at -4.78 dB SNR
# Processed: water_FDRW0_SA1.WAV with babble at -4.55 dB SNR
# Processed: water_FLNH0_SA1.WAV with babble at -6.57 dB SNR
# Processed: water_FMGD0_SA1.WAV with music at -8.02 dB SNR
# Processed: water_MCMJ0_SA1.WAV with babble at -2.87 dB SNR
# Processed: water_MDSC0_SA1.WAV with scenes at -1.36 dB SNR
# Processed: water_MESD0_SA1.WAV with scenes at -3.15 dB SNR
# Processed: water_MJDH0_SA1.WAV with music at -4.64 dB SNR
# Processed: water_MJFC0_SA1.WAV with scenes at -0.99 dB SNR
# Processed: water_MPAM1_SA1.WAV with babble at 0.86 dB SNR
# Processed: water_MRJR0_SA1.WAV with scenes at -4.44 dB SNR
# Processed: water_MRJS0_SA1.WAV with scenes at -0.70 dB SNR
# Processed: water_FCAU0_SA1.WAV with music at -5.18 dB SNR
# Processed: water_FDHC0_SA1.WAV with babble at -4.34 dB SNR
# Processed: water_FGWR0_SA1.WAV with music at -5.85 dB SNR
# Processed: water_FISB0_SA1.WAV with scenes at -2.69 dB SNR
# Processed: water_FLAS0_SA1.WAV with scenes at -4.31 dB SNR
# Processed: water_FMML0_SA1.WAV with babble at 0.88 dB SNR
# Processed: water_FSXA0_SA1.WAV with scenes at -1.16 dB SNR
# Processed: water_FTLH0_SA1.WAV with music at -9.04 dB SNR
# Processed: water_MCHH0_SA1.WAV with music at -7.92 dB SNR
# Processed: water_MDLF0_SA1.WAV with babble at 0.09 dB SNR
# Processed: water_MDVC0_SA1.WAV with music at -3.76 dB SNR
# Processed: water_MERS0_SA1.WAV with babble at -5.18 dB SNR
# Processed: water_MGRT0_SA1.WAV with babble at -3.93 dB SNR
# Processed: water_MKDR0_SA1.WAV with music at -11.12 dB SNR
# Processed: water_MKJL0_SA1.WAV with music at -5.14 dB SNR
# Processed: water_MNJM0_SA1.WAV with music at -6.95 dB SNR
# Processed: water_MNLS0_SA1.WAV with music at -9.16 dB SNR
# Processed: water_MPAB0_SA1.WAV with babble at -5.43 dB SNR
# Processed: water_MRCS0_SA1.WAV with music at -5.81 dB SNR
# Processed: water_MRJM4_SA1.WAV with music at -3.17 dB SNR
# Processed: water_MRMS1_SA1.WAV with music at -5.17 dB SNR
# Processed: water_MRPC0_SA1.WAV with music at -7.29 dB SNR
# Processed: water_MTWH0_SA1.WAV with music at -5.04 dB SNR
# Processed: water_FCMH1_SA1.WAV with music at -5.92 dB SNR
# Processed: water_FJSJ0_SA1.WAV with music at -2.76 dB SNR
# Processed: water_FMLD0_SA1.WAV with scenes at -4.19 dB SNR
# Processed: water_MAJC0_SA1.WAV with music at -2.55 dB SNR
# Processed: water_MDAW1_SA1.WAV with music at -5.99 dB SNR
# Processed: water_MJLN0_SA1.WAV with babble at -5.25 dB SNR
# Processed: water_MJTC0_SA1.WAV with music at -4.42 dB SNR
# Processed: water_MJTH0_SA1.WAV with music at -6.37 dB SNR
# Processed: water_MPAM0_SA1.WAV with babble at -4.57 dB SNR
# Processed: water_MRES0_SA1.WAV with babble at -5.90 dB SNR
# Processed: water_MSLB0_SA1.WAV with babble at 0.67 dB SNR
# Processed: water_FCJF0_SA1.WAV with babble at -5.85 dB SNR
# Processed: water_FDAW0_SA1.WAV with babble at -3.31 dB SNR
# Processed: water_FDML0_SA1.WAV with music at -3.60 dB SNR
# Processed: water_FECD0_SA1.WAV with babble at -2.26 dB SNR
# Processed: water_FETB0_SA1.WAV with babble at -3.02 dB SNR
# Processed: water_FJSP0_SA1.WAV with babble at -2.53 dB SNR
# Processed: water_FKFB0_SA1.WAV with scenes at -4.73 dB SNR
# ...
# Processed: gift_FJLR0_SX61.WAV with babble at -3.47 dB SNR
# Processed: gift_FPAZ0_SI1593.WAV with babble at -0.65 dB SNR
# Processed: gift_MFMC0_SX322.WAV with music at -5.40 dB SNR
# Processed: gift_MRTJ0_SX322.WAV with babble at -3.51 dB SNR
# Processed: gift_MBMA0_SX322.WAV with scenes at -2.80 dB SNR
# Processed: gift_MGAG0_SX61.WAV with music at -7.52 dB SNR
# Processed: gift_FSDC0_SX322.WAV with scenes at 1.55 dB SNR
# Processed: gift_MFER0_SX322.WAV with music at -7.77 dB SNR
# Processed: gift_MPMB0_SX61.WAV with scenes at -3.73 dB SNR
# Processed: gift_FJDM2_SX322.WAV with scenes at -5.22 dB SNR
# Processed: gift_MABC0_SX61.WAV with scenes at -7.41 dB SNR
# Processed: gift_FKDE0_SX61.WAV with scenes at -2.52 dB SNR
# Processed: gift_FLEH0_SX61.WAV with music at -5.16 dB SNR
# Processed: gift_MJDG0_SX322.WAV with music at -8.46 dB SNR
# Processed: gift_MREM0_SX61.WAV with music at -2.46 dB SNR
# Processed: flew_FNTB0_SX303.WAV with babble at -1.37 dB SNR
# Processed: flew_MAPV0_SX303.WAV with music at -6.08 dB SNR
# Processed: flew_MDEF0_SX303.WAV with babble at -2.27 dB SNR
# Processed: flew_MTKP0_SX303.WAV with babble at -2.61 dB SNR
# Processed: flew_MTPG0_SX303.WAV with babble at -7.22 dB SNR
# Processed: flew_FLHD0_SI1974.WAV with scenes at -5.61 dB SNR
# Processed: flew_FBMH0_SI970.WAV with scenes at -4.09 dB SNR
# Processed: flew_FTLG0_SX303.WAV with scenes at -0.14 dB SNR
# Processed: flew_MRLK0_SX303.WAV with babble at -5.38 dB SNR
# Processed: damp_FPAZ0_SI2223.WAV with scenes at -4.12 dB SNR
# Processed: we'd_FSJS0_SI1801.WAV with music at -4.75 dB SNR
# Processed: we'd_MJLS0_SI466.WAV with babble at -5.48 dB SNR
# Processed: wipe_FSJS0_SI1801.WAV with babble at -0.50 dB SNR
# Processed: stay_FSLS0_SI1686.WAV with music at -4.09 dB SNR
# Processed: stay_MLSH0_SI2047.WAV with music at -5.40 dB SNR
# Processed: stay_FPAD0_SI1976.WAV with babble at -1.90 dB SNR
# Processed: davy_FSLS0_SI2316.WAV with scenes at -1.51 dB SNR
# Processed: davy_MSAH1_SI2309.WAV with music at -8.90 dB SNR
# Processed: carl_MADC0_SX17.WAV with babble at -5.75 dB SNR
# Processed: carl_MPRK0_SX17.WAV with music at -2.47 dB SNR
# Processed: carl_MSMC0_SX17.WAV with music at -6.91 dB SNR
# Processed: carl_MJJM0_SX17.WAV with babble at -2.10 dB SNR
# Processed: carl_MSDB0_SX17.WAV with music at -4.16 dB SNR
# Processed: carl_MTER0_SX17.WAV with music at -6.48 dB SNR
# Processed: carl_MTKD0_SX17.WAV with scenes at -3.31 dB SNR
# Processed: axis_MADC0_SX197.WAV with scenes at 0.41 dB SNR
# Processed: axis_MPRK0_SX197.WAV with music at -4.21 dB SNR
# Processed: axis_MSMC0_SX197.WAV with babble at -1.67 dB SNR
# Processed: axis_MEAL0_SX197.WAV with scenes at -1.03 dB SNR
# Processed: axis_MJJM0_SX197.WAV with scenes at -6.90 dB SNR
# Processed: axis_MSDB0_SX197.WAV with scenes at -1.80 dB SNR
# Processed: axis_MTKD0_SX197.WAV with babble at -3.15 dB SNR
# Processed: pays_MADC0_SX287.WAV with babble at 0.22 dB SNR
# Processed: pays_MPRK0_SX287.WAV with music at -5.67 dB SNR
# Processed: pays_MSMC0_SX287.WAV with scenes at -2.96 dB SNR
# Processed: pays_MEAL0_SX287.WAV with babble at -1.18 dB SNR
# Processed: pays_MJJM0_SX287.WAV with babble at -1.05 dB SNR
# Processed: pays_MSDB0_SX287.WAV with babble at 0.44 dB SNR
# Processed: pays_MTKD0_SX287.WAV with babble at -1.28 dB SNR
# Processed: food_MADC0_SX377.WAV with music at -6.59 dB SNR
# Processed: food_MNET0_SI1446.WAV with scenes at -2.46 dB SNR
# Processed: food_MPRK0_SX377.WAV with scenes at -7.03 dB SNR
# Processed: food_MSMC0_SX377.WAV with scenes at -5.00 dB SNR
# Processed: food_MEAL0_SX377.WAV with babble at 0.24 dB SNR
# Processed: food_MJJM0_SX377.WAV with scenes at -3.62 dB SNR
# Processed: food_MSDB0_SX377.WAV with babble at -5.23 dB SNR
# Processed: food_MTKD0_SX377.WAV with babble at -4.11 dB SNR
# Processed: herd_MAKB0_SI1016.WAV with scenes at -3.32 dB SNR
# Processed: cars_MAKR0_SI1982.WAV with scenes at -2.70 dB SNR
# Processed: cars_MTPP0_SI878.WAV with scenes at -0.14 dB SNR
# Processed: cars_FSDJ0_SI485.WAV with scenes at -2.96 dB SNR
# Processed: calm_MCDC0_SI662.WAV with scenes at -1.85 dB SNR
# Processed: heap_MDBB1_SI1636.WAV with music at -9.45 dB SNR
# Processed: chop_MDHS0_SI900.WAV with babble at -4.36 dB SNR
# Processed: chop_FKLC0_SX265.WAV with scenes at -3.46 dB SNR
# Processed: chop_MJMM0_SX265.WAV with scenes at -2.93 dB SNR
# Processed: chop_FTBW0_SX265.WAV with babble at -5.23 dB SNR
# Processed: chop_MJWG0_SX265.WAV with scenes at -6.88 dB SNR
# Processed: chop_FHXS0_SX265.WAV with music at -5.30 dB SNR
# Processed: chop_MDLC1_SX265.WAV with scenes at -3.01 dB SNR
# Processed: chop_MGAW0_SX265.WAV with scenes at -2.83 dB SNR
# Processed: suey_MDHS0_SI900.WAV with babble at -4.63 dB SNR
# Processed: aids_MDJM0_SI825.WAV with music at -4.13 dB SNR
# Processed: slug_MDLH0_SI1960.WAV with scenes at -4.34 dB SNR
# Processed: torn_MDLH0_SI1960.WAV with babble at -5.38 dB SNR
# Processed: gums_MDTB0_SI570.WAV with scenes at -7.01 dB SNR
# Processed: pity_MDWM0_SI1546.WAV with scenes at -2.12 dB SNR
# Processed: gwen_MFMC0_SX412.WAV with scenes at -4.06 dB SNR
# Processed: gwen_MRTJ0_SX412.WAV with music at -6.83 dB SNR
# Processed: gwen_MBMA0_SX412.WAV with music at -8.78 dB SNR
# Processed: gwen_FSDC0_SX412.WAV with music at -2.24 dB SNR
# Processed: gwen_MFER0_SX412.WAV with music at -7.59 dB SNR
# Processed: gwen_FJDM2_SX412.WAV with music at -5.44 dB SNR
# Processed: gwen_MJDG0_SX412.WAV with scenes at -3.06 dB SNR
# Processed: mass_MHJB0_SI1017.WAV with scenes at -2.64 dB SNR
# Processed: mass_MSDS0_SI1707.WAV with scenes at -0.54 dB SNR
# Processed: beep_MHJB0_SI1647.WAV with babble at -4.15 dB SNR
# Processed: buzz_MHJB0_SI1647.WAV with music at -6.20 dB SNR
# Processed: sick_MHJB0_SI2277.WAV with scenes at 4.02 dB SNR
# Processed: park_MILB0_SI807.WAV with scenes at -3.65 dB SNR
# Processed: coal_MJJB0_SI1139.WAV with music at -4.10 dB SNR
# Processed: bath_MJRH1_SI1558.WAV with babble at 1.50 dB SNR
# Processed: bath_MSES0_SI2219.WAV with scenes at -5.65 dB SNR
# Processed: rack_MJRH1_SI1558.WAV with babble at -1.39 dB SNR
# Processed: hint_MJRH1_SI1774.WAV with babble at -4.18 dB SNR
# Processed: rugs_MKLS1_SI915.WAV with music at -6.32 dB SNR
# Processed: mike_MKXL0_SI1815.WAV with music at -7.10 dB SNR
# Processed: able_MKXL0_SI1815.WAV with babble at -4.35 dB SNR
# Processed: able_MBGT0_SI1841.WAV with babble at -3.42 dB SNR
# Processed: able_MJAI0_SI682.WAV with babble at -3.19 dB SNR
# Processed: cent_MLNS0_SI1407.WAV with scenes at -1.22 dB SNR
# Processed: tree_MLNS0_SI2037.WAV with babble at -3.53 dB SNR
# Processed: ease_MLNS0_SI777.WAV with scenes at -4.16 dB SNR
# Processed: ease_MBGT0_SI711.WAV with scenes at -6.98 dB SNR
# Processed: boat_MMJB1_SI778.WAV with music at -6.25 dB SNR
# Processed: boat_MKLN0_SI1598.WAV with scenes at -3.56 dB SNR
# Processed: rang_MMSM0_SI1736.WAV with babble at -1.76 dB SNR
# Processed: mail_MMSM0_SI476.WAV with babble at -2.32 dB SNR
# Processed: floc_MPRD0_SI1431.WAV with babble at -2.35 dB SNR
# Processed: hide_MRDS0_SI1167.WAV with babble at -4.22 dB SNR
# Processed: hide_FSKP0_SI1728.WAV with babble at -3.37 dB SNR
# Processed: swig_MRTJ0_SI2032.WAV with scenes at -2.65 dB SNR
# Processed: hell_MRWA0_SI2233.WAV with music at -5.80 dB SNR
# Processed: hell_MLJC0_SI1225.WAV with babble at -0.76 dB SNR
# Processed: gang_MRWA0_SI2233.WAV with scenes at 0.28 dB SNR
# Processed: rice_MRWA0_SI973.WAV with music at -5.96 dB SNR
# Processed: spun_MTJM0_SI1226.WAV with music at -7.72 dB SNR
# Processed: soak_MTLB0_SI1764.WAV with babble at -2.91 dB SNR
# Processed: pint_FBAS0_SI2066.WAV with babble at -4.53 dB SNR
# Processed: push_FBMJ0_SI815.WAV with music at -5.37 dB SNR
# Processed: push_MJWG0_SI813.WAV with babble at -2.35 dB SNR
# Processed: push_MJWG0_SI895.WAV with babble at -1.51 dB SNR
# Processed: seem_FJWB1_SI2055.WAV with babble at -3.53 dB SNR
# Processed: seem_MSRG0_SI1221.WAV with babble at -4.07 dB SNR
# Processed: seem_FCEG0_SI1248.WAV with music at -6.08 dB SNR
# Processed: seem_MMWS0_SI559.WAV with babble at 0.36 dB SNR
# Processed: rust_FJWB1_SI795.WAV with music at -8.29 dB SNR
# Processed: rust_MKDB0_SI872.WAV with music at -5.63 dB SNR
# Processed: wood_FKLC0_SX265.WAV with music at -4.11 dB SNR
# Processed: wood_MJMM0_SX265.WAV with music at -3.58 dB SNR
# Processed: wood_FTBW0_SX265.WAV with babble at -2.02 dB SNR
# Processed: wood_MJWG0_SX265.WAV with music at -5.64 dB SNR
# Processed: wood_FHXS0_SX265.WAV with music at -5.20 dB SNR
# Processed: wood_MTJU0_SI760.WAV with music at -6.21 dB SNR
# Processed: wood_MDLC1_SX265.WAV with babble at -0.06 dB SNR
# Processed: wood_MGAW0_SX265.WAV with babble at -4.25 dB SNR
# Processed: edgy_FLKM0_SI620.WAV with babble at -1.86 dB SNR
# Processed: ripe_MAEB0_SI1411.WAV with scenes at -3.74 dB SNR
# Processed: ripe_MEGJ0_SI707.WAV with babble at -2.48 dB SNR
# Processed: deed_MBMA0_SI592.WAV with babble at -3.94 dB SNR
# Processed: miss_MBWP0_SI1969.WAV with music at -8.29 dB SNR
# Processed: miss_FJEN0_SI2307.WAV with babble at -5.60 dB SNR
# Processed: seen_MESG0_SI702.WAV with music at -6.09 dB SNR
# Processed: bare_MFRM0_SI1785.WAV with scenes at -3.61 dB SNR
# Processed: bump_MGXP0_SI1087.WAV with babble at -0.67 dB SNR
# Processed: read_MGXP0_SI525.WAV with scenes at -1.19 dB SNR
# Processed: read_MGAK0_SI1666.WAV with babble at 0.44 dB SNR
# Processed: song_MJDC0_SI1161.WAV with music at -1.54 dB SNR
# Processed: song_MBGT0_SI1841.WAV with music at -8.05 dB SNR
# Processed: song_MTKD0_SI630.WAV with scenes at -4.63 dB SNR
# Processed: term_MJEE0_SI607.WAV with music at -6.32 dB SNR
# Processed: term_FEAR0_SI1252.WAV with babble at -4.42 dB SNR
# Processed: it'd_MJLB0_SI1616.WAV with scenes at -2.12 dB SNR
# Processed: knit_MJLS0_SI1096.WAV with music at -3.60 dB SNR
# Processed: dust_MJLS0_SI1726.WAV with music at -8.83 dB SNR
# Processed: dust_MWRE0_SI2317.WAV with scenes at -2.60 dB SNR
# Processed: wish_MJMM0_SI1255.WAV with scenes at -3.66 dB SNR
# Processed: wish_FPAB1_SI2101.WAV with music at -5.48 dB SNR
# Processed: sets_MJMM0_SI1255.WAV with music at -4.66 dB SNR
# Processed: pins_MJSR0_SI794.WAV with babble at -1.21 dB SNR
# Processed: gyro_MKAM0_SI1465.WAV with music at -5.11 dB SNR
# Processed: neck_MLBC0_SI1869.WAV with babble at -2.02 dB SNR
# Processed: rosy_MMBS0_SI521.WAV with babble at -0.00 dB SNR
# Processed: mess_MPRK0_SI1097.WAV with babble at -3.71 dB SNR
# Processed: mess_FSKP0_SI1098.WAV with babble at 0.56 dB SNR
# Processed: tips_MRGM0_SX82.WAV with babble at -3.92 dB SNR
# Processed: tips_FEAR0_SX82.WAV with scenes at -3.37 dB SNR
# Processed: tips_FJRP1_SX82.WAV with babble at -4.68 dB SNR
# Processed: tips_FMKC0_SX82.WAV with scenes at -2.57 dB SNR
# Processed: tips_FBCG1_SX82.WAV with babble at -3.83 dB SNR
# Processed: tips_FNKL0_SX82.WAV with scenes at -1.72 dB SNR
# Processed: tips_MTCS0_SX82.WAV with music at -7.36 dB SNR
# Processed: whip_MRSP0_SI2059.WAV with babble at -3.25 dB SNR
# Processed: soul_MSFH0_SI1216.WAV with music at -4.66 dB SNR
# Processed: bury_MSMC0_SI1907.WAV with scenes at -3.08 dB SNR
# Processed: game_MSRG0_SI1851.WAV with music at -3.74 dB SNR
# Processed: game_MGES0_SI2111.WAV with music at -4.47 dB SNR
# Processed: runs_FBJL0_SI2182.WAV with babble at -1.33 dB SNR
# Processed: runs_FJXM0_SI581.WAV with babble at -1.47 dB SNR
# Processed: runs_MFER0_SI862.WAV with babble at -0.27 dB SNR
# Processed: waxy_FDMY0_SI1197.WAV with babble at -8.11 dB SNR
# Processed: skin_FDMY0_SI1197.WAV with scenes at 0.65 dB SNR
# Processed: cage_FDTD0_SI1561.WAV with music at -8.40 dB SNR
# Processed: gain_FDTD0_SI931.WAV with music at -4.13 dB SNR
# Processed: none_FEAR0_SI622.WAV with music at -7.30 dB SNR
# Processed: none_MDLM0_SI1234.WAV with babble at -4.09 dB SNR
# Processed: none_FJRB0_SI672.WAV with babble at -2.83 dB SNR
# Processed: thaw_FGDP0_SI1618.WAV with music at -4.71 dB SNR
# Processed: shag_FGDP0_SI2248.WAV with babble at -2.75 dB SNR
# Processed: mere_FJXM0_SI1211.WAV with babble at -4.21 dB SNR
# Processed: i've_FLJA0_SI2338.WAV with scenes at -8.37 dB SNR
# Processed: chaw_FLJG0_SI981.WAV with music at -8.70 dB SNR
# Processed: jump_FLMK0_SI1035.WAV with music at -7.88 dB SNR
# Processed: gear_FLMK0_SI1035.WAV with scenes at -2.51 dB SNR
# Processed: pail_FLOD0_SI1287.WAV with babble at -3.35 dB SNR
# Processed: send_FMPG0_SI972.WAV with babble at -3.69 dB SNR
# Processed: send_MTMN0_SI1064.WAV with babble at -3.04 dB SNR
# Processed: iron_FMPG0_SI972.WAV with babble at -2.72 dB SNR
# Processed: iron_MFXS0_SI2225.WAV with music at -4.55 dB SNR
# Processed: iron_FPLS0_SI2220.WAV with music at -7.85 dB SNR
# Processed: knee_FSKP0_SI468.WAV with babble at -2.79 dB SNR
# Processed: role_MBGT0_SI1841.WAV with babble at -1.56 dB SNR
# Processed: scar_MDAS0_SI1896.WAV with babble at -7.72 dB SNR
# Processed: laws_MEWM0_SI718.WAV with music at -5.53 dB SNR
# Processed: vain_MGES0_SI1481.WAV with babble at -2.74 dB SNR
# Processed: flip_MGSH0_SI1806.WAV with music at -6.20 dB SNR
# Processed: coin_MGSH0_SI1806.WAV with music at -6.52 dB SNR
# Processed: clot_MJFH0_SI1737.WAV with scenes at -0.34 dB SNR
# Processed: owns_MJRG0_SI1366.WAV with scenes at -1.31 dB SNR
# Processed: spit_MJRG0_SI736.WAV with music at -4.70 dB SNR
# Processed: diet_MMDM1_SI1650.WAV with music at -7.71 dB SNR
# Processed: lift_MMWB0_SI1619.WAV with babble at -2.79 dB SNR
# Processed: lift_MWCH0_SI2252.WAV with music at -5.68 dB SNR
# Processed: sale_MMWB0_SI2249.WAV with babble at -3.38 dB SNR
# Processed: sour_MSAS0_SI746.WAV with music at -7.32 dB SNR
# Processed: echo_MTMT0_SI1118.WAV with scenes at -2.45 dB SNR
# Processed: saga_MTMT0_SI1118.WAV with scenes at -1.71 dB SNR
# Processed: saws_MTMT0_SI488.WAV with babble at -2.54 dB SNR
# Processed: hurt_MWCH0_SI1895.WAV with scenes at -4.19 dB SNR
# Processed: tame_FJDM2_SI2212.WAV with babble at -3.54 dB SNR
# Processed: cafe_FSGF0_SI1557.WAV with music at -7.27 dB SNR
# Processed: tore_MKES0_SI1883.WAV with music at -7.53 dB SNR
# Processed: puny_MKES0_SI623.WAV with babble at -1.72 dB SNR
# Processed: crew_MRXB0_SI955.WAV with babble at -5.88 dB SNR
# Processed: urge_MSJK0_SI1596.WAV with music at -3.69 dB SNR
# Processed: rove_FMAH1_SI1509.WAV with babble at -3.82 dB SNR
# Processed: lazy_FPAB1_SI1471.WAV with babble at -1.97 dB SNR
# Processed: lazy_MKAG0_SI1609.WAV with music at -6.67 dB SNR
# Processed: riot_FPAB1_SI2101.WAV with music at -7.72 dB SNR
# Processed: rate_FREH0_SI685.WAV with scenes at -0.97 dB SNR
# Processed: kick_MAEO0_SI1956.WAV with music at -4.02 dB SNR
# Processed: goal_MAFM0_SI1569.WAV with scenes at -0.49 dB SNR
# Processed: code_MBAR0_SI689.WAV with babble at -2.98 dB SNR
# Processed: lock_MBBR0_SI1685.WAV with babble at -2.60 dB SNR
# Processed: bomb_MBTH0_SI505.WAV with music at -3.64 dB SNR
# Processed: zeal_MCRE0_SI1121.WAV with scenes at -4.99 dB SNR
# Processed: kayo_MDED0_SI1800.WAV with scenes at 1.76 dB SNR
# Processed: mate_MDKS0_SI2326.WAV with scenes at -0.12 dB SNR
# Processed: grip_MDLC1_SI2065.WAV with scenes at -5.71 dB SNR
# Processed: atop_MDLM0_SI604.WAV with scenes at -4.46 dB SNR
# Processed: desk_MDPB0_SI2126.WAV with music at -7.51 dB SNR
# Processed: desk_MKLR0_SI2319.WAV with babble at 1.32 dB SNR
# Processed: desk_MWRE0_SI2317.WAV with babble at -2.26 dB SNR
# Processed: tour_MJFR0_SI975.WAV with scenes at -2.69 dB SNR
# Processed: pace_MJRA0_SI1866.WAV with scenes at -3.69 dB SNR
# Processed: guys_MKAG0_SI2239.WAV with scenes at -2.28 dB SNR
# Processed: wise_MPAR0_SI2206.WAV with scenes at -0.94 dB SNR
# Processed: hire_MPAR0_SI946.WAV with babble at -5.73 dB SNR
# Processed: ends_MRMH0_SI1349.WAV with music at -8.83 dB SNR
# Processed: nuts_MSDB0_SI1007.WAV with scenes at -0.37 dB SNR
# Processed: bold_MSES0_SI1589.WAV with scenes at -1.37 dB SNR
# Processed: ward_MTKD0_SI1817.WAV with babble at -1.77 dB SNR
# Processed: ward_MKDD0_SI2197.WAV with music at -6.56 dB SNR
# Processed: duck_MTPR0_SI2230.WAV with music at -8.43 dB SNR
# Processed: taxi_MVRW0_SI1485.WAV with scenes at -2.68 dB SNR
# Processed: laid_MWRP0_SI2073.WAV with music at -5.44 dB SNR
# Processed: tool_MCXM0_SI721.WAV with scenes at -6.07 dB SNR
# Processed: belt_MEJS0_SI1870.WAV with music at -3.97 dB SNR
# Processed: copy_MEJS0_SI610.WAV with scenes at -1.52 dB SNR
# Processed: fame_MKRG0_SI2121.WAV with music at -6.52 dB SNR
# Processed: fled_MMLM0_SI2150.WAV with music at -2.85 dB SNR

# %%
pip install librosa.output
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement librosa.output (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for librosa.output
